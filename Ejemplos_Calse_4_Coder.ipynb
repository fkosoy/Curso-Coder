# %% [markdown]
# <a href="https://colab.research.google.com/github/fkosoy/Curso-Coder/blob/main/Ejemplos_Calse_4_Coder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datos = {'Nombre': ['   Carlos', 'Jorge   ', 'Cris'], 'Correo': ['CS@gmail.com', 'JS@hotmail.com', 'CSS@yahoo.com'], 'Pais': ['Mexico', 'Peru', 'Chile']}
dataframe = pd.DataFrame(datos)
print(dataframe)
# Out:
#       Nombre          Correo    Pais
# 0     Carlos    CS@gmail.com  Mexico
# 1   Jorge     JS@hotmail.com    Peru
# 2       Cris   CSS@yahoo.com   Chile

# %%
#recorto correo
dataframe['dominio'] = dataframe['Correo'].str.split('@').str[1]
print(dataframe)
# Out:
#       Nombre          Correo    Pais      dominio
# 0     Carlos    CS@gmail.com  Mexico    gmail.com
# 1   Jorge     JS@hotmail.com    Peru  hotmail.com
# 2       Cris   CSS@yahoo.com   Chile    yahoo.com

# %%
#reemplazo variable
dataframe['Nombre'] = dataframe['Nombre'].str.replace('Carlos','Hector')
print(dataframe)
# Out:
#       Nombre          Correo    Pais      dominio
# 0     Hector    CS@gmail.com  Mexico    gmail.com
# 1   Jorge     JS@hotmail.com    Peru  hotmail.com
# 2       Cris   CSS@yahoo.com   Chile    yahoo.com

# %%
#elimino espacios
dataframe['Nombre'] = dataframe['Nombre'].str.strip()
print(dataframe)
# Out:
#    Nombre          Correo    Pais      dominio
# 0  Hector    CS@gmail.com  Mexico    gmail.com
# 1   Jorge  JS@hotmail.com    Peru  hotmail.com
# 2    Cris   CSS@yahoo.com   Chile    yahoo.com

# %%
import numpy as np
import pandas as pd

# %%
#creaion serie de tiempo
fechas = pd.date_range(start='2024/01/01', end='2025/01/01', freq='D')
print(fechas)
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10',
#                ...
#                '2024-12-23', '2024-12-24', '2024-12-25', '2024-12-26',
#                '2024-12-27', '2024-12-28', '2024-12-29', '2024-12-30',
#                '2024-12-31', '2025-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
import matplotlib.pyplot as plt
import numpy as np
# creo ejes y valores con arrays de np
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.figure(figsize=(10, 5))
plt.plot(x, y, label= 'Seno de x')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Función Seno')
plt.legend()
plt.grid(True)
plt.show()

# %%
x = np.random.rand(100)
y = np.random.rand(100)
plt.figure(figsize=(10,5))
plt.scatter(x, y, color='green', alpha=0.9)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gráfico de Dispersión')
plt.grid(True)
plt.show()
